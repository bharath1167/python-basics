# %% [markdown]
# # **Project-7:Project-7:Orange Quality Analysis**

# %% [markdown]
# #import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Load Dataset

# %%
a = pd.read_csv('/content/Project-7_Orange Quality Data.csv')

# %%
#shape
a.shape
# Out:
# (241, 11)

# %%
#info
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Size (cm)           241 non-null    float64
#  1   Weight (g)          241 non-null    int64
#  2   Brix (Sweetness)    241 non-null    float64
#  3   pH (Acidity)        241 non-null    float64
#  4   Softness (1-5)      241 non-null    float64
#  5   HarvestTime (days)  241 non-null    int64
#  6   Ripeness (1-5)      241 non-null    float64
#  7   Color               241 non-null    object
#  8   Variety             241 non-null    object
#  9   Blemishes (Y/N)     241 non-null    object
#  10  Quality (1-5)       241 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.8+ KB

# %%
#Describe
a.describe()
# Out:
#         Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  241.000000  241.000000        241.000000    241.000000      241.000000
# mean     7.844813  205.128631         10.907884      3.473900        3.072614
# std      1.086002   56.461012          2.760446      0.421007        1.323630
# min      6.000000  100.000000          5.500000      2.800000        1.000000
# 25%      6.900000  155.000000          8.500000      3.200000        2.000000
# 50%      7.800000  205.000000         11.000000      3.400000        3.000000
# 75%      8.700000  252.000000         13.400000      3.800000        4.000000
# max     10.000000  300.000000         16.000000      4.400000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count          241.000000      241.000000     241.000000
# mean            15.344398        3.599585       3.817427
# std              5.323852        1.205214       1.014410
# ...

# %%
#Head
a.head(2)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
#
#    HarvestTime (days)  Ripeness (1-5)        Color   Variety Blemishes (Y/N)  \
# 0                  10             4.0       Orange  Valencia               N
# 1                  14             4.5  Deep Orange     Navel               N
#
#    Quality (1-5)
# 0            4.0
# 1            4.5

# %%
#tail
a.tail(2)
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
#      HarvestTime (days)  Ripeness (1-5)         Color       Variety  \
# 239                  23             1.0  Light Orange  Moro (Blood)
# 240                  21             2.0    Orange-Red         Jaffa
#
#              Blemishes (Y/N)  Quality (1-5)
# 239  Y (Minor Insect Damage)            3.0
# 240                Y (Minor)            4.0

# %%
#find null values
a.isnull().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %%
#basic plot
#lineplot
sns.lineplot(x='Variety',y'Weight',data = a)
# Out:
#   File "<ipython-input-25-8ffa56017f65>", line 3
#     sns.lineplot(x='Variety',y'Weight',data = a)
#                                             ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# #Question-1:Is there a correlation between the size (Size (cm)) and the weight (Weight (g)) of the fruit?

# %%
a[['Size (cm)', 'Weight (g)']].corr()
# Out:
#             Size (cm)  Weight (g)
# Size (cm)    1.000000    0.305348
# Weight (g)   0.305348    1.000000

# %% [markdown]
# #question-2:How does the sweetness (Brix) of the fruit correlate with its acidity (pH)? Do sweeter fruits have lower acidity?

# %%
a[['Brix (Sweetness)', 'pH (Acidity)']].corr()
# Out:
#                   Brix (Sweetness)  pH (Acidity)
# Brix (Sweetness)           1.00000      -0.30008
# pH (Acidity)              -0.30008       1.00000

# %% [markdown]
# #Question-3:How does the softness (Softness (1-5)) of the fruit relate to its ripeness (Ripeness (1-5))?

# %%
a[['Softness (1-5)', 'Ripeness (1-5)']].corr()
# Out:
#                 Softness (1-5)  Ripeness (1-5)
# Softness (1-5)        1.000000       -0.202404
# Ripeness (1-5)       -0.202404        1.000000

# %% [markdown]
# #Question-4: Do fruits with blemishes (Blemishes (Y/N)) tend to have lower ripeness or softness levels?

# %%
a.groupby('Blemishes (Y/N)')[['Ripeness (1-5)', 'Softness (1-5)']].mean()
# Out:
#                          Ripeness (1-5)  Softness (1-5)
# Blemishes (Y/N)
# N                              3.906040        2.986577
# N (Minor)                      4.000000        4.000000
# N (Split Skin)                 2.000000        5.000000
# Y (Bruise)                     3.500000        3.500000
# Y (Bruising)                   3.333333        3.388889
# Y (Minor Insect Damage)        2.750000        2.916667
# Y (Minor)                      3.357143        2.178571
# Y (Mold Spot)                  3.150000        4.000000
# Y (Scars)                      3.235294        3.382353
# Y (Split Skin)                 3.125000        3.375000
# Y (Sunburn Patch)              2.913043        3.086957
# Y (Sunburn)                    2.000000        4.500000

# %% [markdown]
# #Question-5:How do different fruit varieties (Variety) differ in terms of size, weight, sweetness, acidity, and ripeness?

# %%
a.groupby('Variety')[['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)', 'Ripeness (1-5)']].describe()
# Out:
#                       Size (cm)                                               \
#                           count      mean       std  min    25%   50%    75%
# Variety
# Ambiance                   11.0  7.827273  0.912240  6.4  7.250  7.60  8.450
# Blood Orange                2.0  9.500000  0.707107  9.0  9.250  9.50  9.750
# California Valencia         7.0  7.885714  0.481070  7.3  7.450  8.10  8.200
# Cara Cara                  21.0  8.419048  1.338140  6.1  7.000  8.90  9.600
# Clementine                 14.0  7.578571  0.976003  6.2  6.800  7.45  8.375
# Clementine (Seedless)       4.0  6.500000  0.216025  6.2  6.425  6.55  6.625
# Hamlin                      5.0  8.160000  0.270185  7.8  8.000  8.20  8.300
# Honey Tangerine             7.0  7.742857  1.171690  6.1  6.850  7.90  8.600
# Jaffa                      11.0  7.090909  0.684769  6.1  6.450  7.30  7.550
# Midsweet (Hybrid)           5.0  8.660000  0.181659  8.5  8.500  8.60  8.800
# ...

# %%
a.head(2)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
#
#    HarvestTime (days)  Ripeness (1-5)        Color   Variety Blemishes (Y/N)  \
# 0                  10             4.0       Orange  Valencia               N
# 1                  14             4.5  Deep Orange     Navel               N
#
#    Quality (1-5)
# 0            4.0
# 1            4.5
