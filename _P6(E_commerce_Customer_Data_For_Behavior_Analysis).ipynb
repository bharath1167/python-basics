# %% [markdown]
# # **Project-6:E-commerce Customer Data For Behavior Analysis**

# %% [markdown]
# #Install packages

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# #Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Load Dataset

# %%
a = pd.read_csv('/content/Project-6_ecommerce_customer_data_custom_ratios.csv')

# %%
#shape
a.shape
# Out:
# (250000, 13)

# %%
#info
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %%
#description
a.describe()
# Out:
#         Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.00000  250000.000000  250000.000000          250000.000000
# mean    25004.03624     254.659512       2.998896            2725.370732
# std     14428.27959     141.568577       1.414694            1442.933565
# min         1.00000      10.000000       1.000000             100.000000
# 25%     12497.75000     132.000000       2.000000            1477.000000
# 50%     25018.00000     255.000000       3.000000            2724.000000
# 75%     37506.00000     377.000000       4.000000            3974.000000
# max     50000.00000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age          Churn
# count  250000.000000  202404.000000  250000.000000  250000.000000
# mean       43.940528       0.497861      43.940528       0.199496
# std        15.350246       0.499997      15.350246       0.399622
# ...

# %%
#head
a.head(2)
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
#
#          Customer Name  Age Gender  Churn
# 0  Christine Hernandez   37   Male      0
# 1  Christine Hernandez   37   Male      0

# %%
#tail
a.tail(2)
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 249998         2                   3668         Crypto            34      0.0
# 249999         4                   2370           Cash            36      1.0
#
#           Customer Name  Age  Gender  Churn
# 249998  Jennifer Cooper   34  Female      1
# 249999    Justin Lawson   36  Female      1

# %%
#find null values
a.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47596
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
#fill null values
a['Returns'].fillna(a['Returns'].mode()[0],inplace = True)
# Out:
# <ipython-input-10-a7a3be9a69f3>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['Returns'].fillna(a['Returns'].mode()[0],inplace = True)

# %%
a.isnull().sum()
# Out:
# Customer ID              0
# Purchase Date            0
# Product Category         0
# Product Price            0
# Quantity                 0
# Total Purchase Amount    0
# Payment Method           0
# Customer Age             0
# Returns                  0
# Customer Name            0
# Age                      0
# Gender                   0
# Churn                    0
# dtype: int64

# %%
#basic plots
#lineplot
sns.lineplot(x = 'Product Category',y = 'Quantity',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Quantity'>

# %%
#barplot
sns.barplot(x = 'Product Category',y = 'Quantity',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Quantity'>

# %%
#scatterplot
sns.scatterplot(x = 'Product Category',y = 'Quantity',hue='Gender',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Quantity'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#univariate
#histogram
sns.histplot(a['Quantity'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
#box plot
sns.boxplot(a['Quantity'])
# Out:
# <Axes: ylabel='Quantity'>

# %%
#vioin plot
sns.violinplot(a['Quantity'])
# Out:
# <Axes: ylabel='Quantity'>

# %%
#bivariate
#scatterplot
sns.scatterplot(x = 'Product Category',y = 'Product Price',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Product Price'>

# %%
#box plot
sns.boxplot(x = 'Product Category',y = 'Product Price',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Product Price'>

# %%
#violin plot
sns.violinplot(x = 'Product Category',y = 'Product Price',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Product Price'>

# %%
#multivariate
#pairplot
sns.pairplot(a)

# %%
#jointplot
sns.jointplot(x = 'Product Category',y = 'Product Price',data = a)

# %%
a.head(5)
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %% [markdown]
# #Question-1:What are the trends in total purchase amount over time (based on Purchase Date)? Are there any seasonal patterns?

# %%
sns.lineplot(x = 'Purchase Date',y = 'Total Purchase Amount',data = a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-520df5e545ca> in <cell line: 0>()
# ----> 1 sns.lineplot(x = 'Purchase Date',y = 'Total Purchase Amount',data = a)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #Question-2:Which product categories generate the highest revenue and which are the most popular based on quantity purchased?

# %%
sns.barplot(x = 'Product Category',y = 'Total Purchase Amount',data = a)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Purchase Amount'>

# %%
a.groupby('Product Category')['Quantity'].sum()
# Out:
# Product Category
# Books          223876
# Clothing       225322
# Electronics    150828
# Home           149698
# Name: Quantity, dtype: int64

# %% [markdown]
# #Question-3:What are the most popular payment methods, and how do they relate to the total purchase amount or frequency of purchases?

# %%
#What are the most popular payment methods, and how do they relate to the total purchase amount or frequency of purchases?
sns.scatterplot(x = 'Payment Method',y = 'Total Purchase Amount',data = a)
# Out:
# <Axes: xlabel='Payment Method', ylabel='Total Purchase Amount'>

# %% [markdown]
# #Question-4:Who are the top customers by total purchase amount or frequency, based on Customer ID and Customer Name?

# %%
sns.barplot(x = 'Customer ID',y = 'Total Purchase Amount',data = a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-cd01642091da> in <cell line: 0>()
# ----> 1 sns.barplot(x = 'Customer ID',y = 'Total Purchase Amount',data = a)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2378     err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
#    2379
# -> 2380     p.plot_bars(
#    2381         aggregator=aggregator,
#    2382         dodge=dodge,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1278
# ...
