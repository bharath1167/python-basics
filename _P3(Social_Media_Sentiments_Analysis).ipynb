# %% [markdown]
# # **Project-3:Social Media Sentiments Analysis**

# %% [markdown]
# #Step-1:install Packages

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# # Step-2:Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step-3: Load dataset

# %%
a = pd.read_csv("/content/Project-3_sentimentdataset.csv")

# %%
#head
a.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#tail
a.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
#info
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
#describe
a.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
#shape
a.shape
# Out:
# (732, 15)

# %%
# nullvalues
a.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %% [markdown]
# #Step-4: ploting

# %%
#lineplot
sns.lineplot(x='Hour',y='Likes',data=a)
# Out:
# <Axes: xlabel='Hour', ylabel='Likes'>

# %%
#bar plot
sns.barplot(x='Hour',y='Likes',data=a)
# Out:
# <Axes: xlabel='Hour', ylabel='Likes'>

# %%
#scatter plot
sns.scatterplot(x='Hour',y='Likes',data=a)
# Out:
# <Axes: xlabel='Hour', ylabel='Likes'>

# %%
#univariate
#histogram
sns.histplot(a['Likes'])
# Out:
# <Axes: xlabel='Likes', ylabel='Count'>

# %%
#box plot
sns.boxplot(a['Likes'])
# Out:
# <Axes: ylabel='Likes'>

# %%
#violin plot
sns.violinplot(a['Likes'])
# Out:
# <Axes: ylabel='Likes'>

# %%
#count plot
sns.countplot(a['Platform'])
# Out:
# <Axes: xlabel='count', ylabel='Platform'>

# %%
#bivariate
#scatter plot
sns.scatterplot(x='Likes',y='Retweets',data=a)
# Out:
# <Axes: xlabel='Likes', ylabel='Retweets'>

# %%
#boxplot
sns.boxplot(x='Platform',y='Likes',data=a)
# Out:
# <Axes: xlabel='Platform', ylabel='Likes'>

# %%
#violin plot
sns.violinplot(x='Platform',y='Likes',data=a)
# Out:
# <Axes: xlabel='Platform', ylabel='Likes'>

# %%
#multivariate
#pairplot
sns.pairplot(a)

# %%
#jointplot
sns.jointplot(x='Likes',y='Retweets',data=a)

# %% [markdown]
# # Question-1:What is the overall distribution of sentiments (positive, negative, neutral) across the posts?

# %%
a['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive           44
# Joy                42
# Excitement         32
# Neutral            14
# Contentment        14
#                    ..
# Adrenaline          1
# Harmony             1
# ArtisticBurst       1
# Radiance            1
# Elegance            1
# Name: count, Length: 279, dtype: int64

# %% [markdown]
# # Question-2:Which platform generates the most engagement in terms of likes and retweets?

# %%
a.groupby('Platform')['Likes'].sum()
# Out:
# Platform
# Facebook       9672.0
# Instagram     11633.0
# Twitter        5809.0
# Twitter        4290.0
# Name: Likes, dtype: float64

# %%
a.groupby('Platform')['Retweets'].sum()
# Out:
# Platform
# Facebook      4844.0
# Instagram     5831.0
# Twitter       2918.0
# Twitter       2151.0
# Name: Retweets, dtype: float64

# %% [markdown]
# # Question-3:Which users have the highest average engagement (likes and retweets per post)?

# %%
a.groupby('User')['Likes'].mean()
# Out:
# User
# AbyssOfTime               45.0
# AcceptanceSeeker          30.0
# AdeleConcertGoer          80.0
# AdeleMelodyTearjerker     60.0
# AdventureAwaits           40.0
#                           ...
# YearbookExplorer          25.0
# ZenLifestyle              30.0
# ZenMaster                 30.0
# ZenMaster2                35.0
# ZenSeeker                 70.0
# Name: Likes, Length: 685, dtype: float64

# %%
a.groupby('User')['Retweets'].mean()
# Out:
# User
# AbyssOfTime               22.0
# AcceptanceSeeker          15.0
# AdeleConcertGoer          40.0
# AdeleMelodyTearjerker     30.0
# AdventureAwaits           20.0
#                           ...
# YearbookExplorer          12.0
# ZenLifestyle              15.0
# ZenMaster                 15.0
# ZenMaster2                18.0
# ZenSeeker                 35.0
# Name: Retweets, Length: 685, dtype: float64
